# %%
import pandas as pd
import numpy as np
#data = pd.read_csv('data/Compressed Mortality, 2016.txt', sep=" ", header=None)
#data.columns = ["a", "b", "c", "etc."]
#data = pd.read_fwf('data/Compressed Mortality, 2016.txt')


from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt
% matplotlib inline

# %%
# Compressed Mortality

# get a list of the data files the direction
onlyfiles = [f for f in listdir('data/Compressed Mortality/') if isfile(join('data/Compressed Mortality/', f))]
print(onlyfiles)

# for each txt file...
for i in np.arange(len(onlyfiles)):

    data_temp = pd.read_table('data/Compressed Mortality/' + onlyfiles[i], header='infer', index_col=None,  names=('Notes', 'County', 'County Code', 'Deaths', 'Population', 'Crude Rate'))
    #data_temp.drop(data_temp.index[0])
    data_dropped = data_temp.iloc[1:] #Remove the first row because it's the files's header
    data_dropped['County Code'] = pd.to_numeric(data_dropped['County Code']) # Make the zipcode a float instead of a string
    print(data_dropped.head(5))

    data_dropped.insert(0, 'year', onlyfiles[i][-8:-4]) # Add the year as a column
#print(data.head)
    if i == 0:
        data = data_dropped
    else:
        data = pd.concat([data, data_dropped]) # add each year's text file to the overall dataframe


data_sorted = data.sort_values(by=['County Code', 'year']) # put in order

#print(data_sorted.head(5))

data_mortality = data_sorted


data_mortality.set_index(['County Code', 'year'], inplace=True, drop =False)

print(data_mortality.head(20))

#print(data.iloc[2000])
# Out:
# ['Compressed Mortality, 1999.txt', 'Compressed Mortality, 2000.txt', 'Compressed Mortality, 2001.txt', 'Compressed Mortality, 2002.txt', 'Compressed Mortality, 2003.txt', 'Compressed Mortality, 2004.txt', 'Compressed Mortality, 2005.txt', 'Compressed Mortality, 2006.txt', 'Compressed Mortality, 2007.txt', 'Compressed Mortality, 2008.txt', 'Compressed Mortality, 2009.txt', 'Compressed Mortality, 2010.txt', 'Compressed Mortality, 2011.txt', 'Compressed Mortality, 2012.txt', 'Compressed Mortality, 2013.txt', 'Compressed Mortality, 2014.txt', 'Compressed Mortality, 2015.txt', 'Compressed Mortality, 2016.txt']
#   Notes                 County  County Code Deaths Population  \
# 1   NaN     Baldwin County, AL       1003.0     11     137555
# 2   NaN   Jefferson County, AL       1073.0     34     662845
# 3   NaN     Madison County, AL       1089.0     10     274692
# 4   NaN      Mobile County, AL       1097.0     28     399323
# 5   NaN  Anchorage Borough, AK       2020.0     21     259348
#
#          Crude Rate
# 1  8.0 (Unreliable)
# 2               5.1
# 3  3.6 (Unreliable)
# 4               7.0
# 5               8.1
#   Notes                 County  County Code Deaths Population  \
# 1   NaN     Baldwin County, AL       1003.0     12     140415
# 2   NaN      Etowah County, AL       1055.0     10     103459
# 3   NaN   Jefferson County, AL       1073.0     47     662047
# 4   NaN      Mobile County, AL       1097.0     32     399843
# 5   NaN  Anchorage Borough, AK       2020.0     21     260283
#
#          Crude Rate
# 1  8.5 (Unreliable)
# 2  9.7 (Unreliable)
# 3               7.1
# 4               8.0
# 5               8.1
#   Notes                 County  County Code Deaths Population  \
# 1   NaN     Baldwin County, AL       1003.0     12     144875
# 2   NaN   Jefferson County, AL       1073.0     46     660197
# 3   NaN      Mobile County, AL       1097.0     28     400129
# 4   NaN  Anchorage Borough, AK       2020.0     36     264274
# 5   NaN     Cochise County, AZ       4003.0     12     118798
#
#           Crude Rate
# 1   8.3 (Unreliable)
# 2                7.0
# 3                7.0
# 4               13.6
# 5  10.1 (Unreliable)
#   Notes                            County  County Code Deaths Population  \
# 1   NaN                Baldwin County, AL       1003.0     16     147957
# 2   NaN              Jefferson County, AL       1073.0     47     657518
# 3   NaN                 Mobile County, AL       1097.0     33     398549
# 4   NaN             Anchorage Borough, AK       2020.0     41     268229
# 5   NaN  Fairbanks North Star Borough, AK       2090.0     11      86095
#
#           Crude Rate
# 1  10.8 (Unreliable)
# 2                7.1
# 3                8.3
# 4               15.3
# 5  12.8 (Unreliable)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#   Notes                 County  County Code Deaths Population  \
# 1   NaN     Baldwin County, AL       1003.0     12     151509
# 2   NaN      Etowah County, AL       1055.0     10     103025
# 3   NaN   Jefferson County, AL       1073.0     46     657513
# 4   NaN      Mobile County, AL       1097.0     33     398082
# 5   NaN  Anchorage Borough, AK       2020.0     39     270568
#
#          Crude Rate
# 1  7.9 (Unreliable)
# 2  9.7 (Unreliable)
# 3               7.0
# 4               8.3
# 5              14.4
#   Notes                 County  County Code Deaths Population  \
# 1   NaN     Baldwin County, AL       1003.0     20     156266
# 2   NaN   Jefferson County, AL       1073.0     54     656023
# 3   NaN     Madison County, AL       1089.0     17     295655
# 4   NaN      Mobile County, AL       1097.0     31     397959
# 5   NaN  Montgomery County, AL       1101.0     13     223002
#
#          Crude Rate
# 1              12.8
# 2               8.2
# 3  5.7 (Unreliable)
# 4               7.8
# 5  5.8 (Unreliable)
#   Notes                County  County Code Deaths Population  \
# 1   NaN    Baldwin County, AL       1003.0     22     162183
# 2   NaN    Calhoun County, AL       1015.0     10     114477
# 3   NaN     Etowah County, AL       1055.0     11     103174
# 4   NaN  Jefferson County, AL       1073.0     51     654919
# 5   NaN    Madison County, AL       1089.0     15     301474
#
#           Crude Rate
# 1               13.6
# 2   8.7 (Unreliable)
# 3  10.7 (Unreliable)
# 4                7.8
# 5   5.0 (Unreliable)
#   Notes                County  County Code Deaths Population  \
# 1   NaN    Baldwin County, AL       1003.0     21     168121
# 2   NaN    Chilton County, AL       1021.0     13      42318
# 3   NaN     Etowah County, AL       1055.0     10     103528
# 4   NaN  Jefferson County, AL       1073.0     65     655893
# 5   NaN     Mobile County, AL       1097.0     39     402916
#
#           Crude Rate
# 1               12.5
# 2  30.7 (Unreliable)
# 3   9.7 (Unreliable)
# 4                9.9
# 5                9.7
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     28     172404               16.2
# 2   NaN  Calhoun County, AL       1015.0     13     116211  11.2 (Unreliable)
# 3   NaN   DeKalb County, AL       1049.0     11      69450  15.8 (Unreliable)
# 4   NaN   Etowah County, AL       1055.0     13     103893  12.5 (Unreliable)
# 5   NaN  Houston County, AL       1069.0     10      97727  10.2 (Unreliable)
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     27     175827               15.4
# 2   NaN   Blount County, AL       1009.0     17      57055  29.8 (Unreliable)
# 3   NaN  Calhoun County, AL       1015.0     21     117274               17.9
# 4   NaN  Cullman County, AL       1043.0     11      80273  13.7 (Unreliable)
# 5   NaN   DeKalb County, AL       1049.0     11      70228  15.7 (Unreliable)
#   Notes               County  County Code Deaths Population         Crude Rate
# 1   NaN   Baldwin County, AL       1003.0     32     179406               17.8
# 2   NaN    Blount County, AL       1009.0     11      57341  19.2 (Unreliable)
# 3   NaN   Calhoun County, AL       1015.0     15     118363  12.7 (Unreliable)
# 4   NaN    DeKalb County, AL       1049.0     14      70864  19.8 (Unreliable)
# 5   NaN  Escambia County, AL       1053.0     17      38249  44.4 (Unreliable)
#   Notes               County  County Code Deaths Population         Crude Rate
# 1   NaN   Baldwin County, AL       1003.0     26     182265               14.3
# 2   NaN    Blount County, AL       1009.0     10      57322  17.4 (Unreliable)
# 3   NaN   Calhoun County, AL       1015.0     21     118572               17.7
# 4   NaN   Chilton County, AL       1021.0     11      43643  25.2 (Unreliable)
# 5   NaN  Escambia County, AL       1053.0     10      38319  26.1 (Unreliable)
#   Notes               County  County Code Deaths Population         Crude Rate
# 1   NaN   Baldwin County, AL       1003.0     24     186653               12.9
# 2   NaN   Calhoun County, AL       1015.0     14     117736  11.9 (Unreliable)
# 3   NaN   Cullman County, AL       1043.0     10      80457  12.4 (Unreliable)
# 4   NaN    DeKalb County, AL       1049.0     11      71389  15.4 (Unreliable)
# 5   NaN  Escambia County, AL       1053.0     16      38227  41.9 (Unreliable)
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     34     190403               17.9
# 2   NaN   Blount County, AL       1009.0     17      57772  29.4 (Unreliable)
# 3   NaN  Cullman County, AL       1043.0     12      80351  14.9 (Unreliable)
# 4   NaN   DeKalb County, AL       1049.0     16      70961  22.5 (Unreliable)
# 5   NaN  Houston County, AL       1069.0     10     103382   9.7 (Unreliable)
#   Notes               County  County Code Deaths Population         Crude Rate
# 1   NaN   Baldwin County, AL       1003.0     22     195147               11.3
# 2   NaN    Blount County, AL       1009.0     13      57746  22.5 (Unreliable)
# 3   NaN   Cullman County, AL       1043.0     16      80731  19.8 (Unreliable)
# 4   NaN    DeKalb County, AL       1049.0     23      70882               32.4
# 5   NaN  Escambia County, AL       1053.0     13      37877  34.3 (Unreliable)
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     38     199745               19.0
# 2   NaN   Blount County, AL       1009.0     12      57621  20.8 (Unreliable)
# 3   NaN  Calhoun County, AL       1015.0     19     115837  16.4 (Unreliable)
# 4   NaN  Cullman County, AL       1043.0     30      81167               37.0
# 5   NaN   Elmore County, AL       1051.0     10      80794  12.4 (Unreliable)
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     43     203690               21.1
# 2   NaN   Blount County, AL       1009.0     11      57676  19.1 (Unreliable)
# 3   NaN  Calhoun County, AL       1015.0     20     115285               17.3
# 4   NaN  Cullman County, AL       1043.0     16      81858  19.5 (Unreliable)
# 5   NaN   DeKalb County, AL       1049.0     19      70996  26.8 (Unreliable)
#   Notes              County  County Code Deaths Population         Crude Rate
# 1   NaN  Baldwin County, AL       1003.0     32     208563               15.3
# 2   NaN   Blount County, AL       1009.0     14      57704  24.3 (Unreliable)
# 3   NaN  Calhoun County, AL       1015.0     15     114611  13.1 (Unreliable)
# 4   NaN  Cullman County, AL       1043.0     19      82471  23.0 (Unreliable)
# 5   NaN   DeKalb County, AL       1049.0     18      70900  25.4 (Unreliable)
#                   year Notes              County  County Code Deaths  \
# County Code year
# 1003.0      1999  1999   NaN  Baldwin County, AL       1003.0     11
#             2000  2000   NaN  Baldwin County, AL       1003.0     12
#             2001  2001   NaN  Baldwin County, AL       1003.0     12
#             2002  2002   NaN  Baldwin County, AL       1003.0     16
#             2003  2003   NaN  Baldwin County, AL       1003.0     12
#             2004  2004   NaN  Baldwin County, AL       1003.0     20
#             2005  2005   NaN  Baldwin County, AL       1003.0     22
#             2006  2006   NaN  Baldwin County, AL       1003.0     21
#             2007  2007   NaN  Baldwin County, AL       1003.0     28
#             2008  2008   NaN  Baldwin County, AL       1003.0     27
#             2009  2009   NaN  Baldwin County, AL       1003.0     32
#             2010  2010   NaN  Baldwin County, AL       1003.0     26
#             2011  2011   NaN  Baldwin County, AL       1003.0     24
#             2012  2012   NaN  Baldwin County, AL       1003.0     34
#             2013  2013   NaN  Baldwin County, AL       1003.0     22
#             2014  2014   NaN  Baldwin County, AL       1003.0     38
#             2015  2015   NaN  Baldwin County, AL       1003.0     43
#             2016  2016   NaN  Baldwin County, AL       1003.0     32
# 1009.0      2008  2008   NaN   Blount County, AL       1009.0     17
#             2009  2009   NaN   Blount County, AL       1009.0     11
#
#                  Population         Crude Rate
# County Code year
# 1003.0      1999     137555   8.0 (Unreliable)
#             2000     140415   8.5 (Unreliable)
#             2001     144875   8.3 (Unreliable)
#             2002     147957  10.8 (Unreliable)
#             2003     151509   7.9 (Unreliable)
#             2004     156266               12.8
#             2005     162183               13.6
#             2006     168121               12.5
#             2007     172404               16.2
#             2008     175827               15.4
#             2009     179406               17.8
#             2010     182265               14.3
#             2011     186653               12.9
#             2012     190403               17.9
#             2013     195147               11.3
#             2014     199745               19.0
#             2015     203690               21.1
#             2016     208563               15.3
# 1009.0      2008      57055  29.8 (Unreliable)
#             2009      57341  19.2 (Unreliable)

# %%
# perscrption drugs

# Get all the relevant csv files
onlyfiles = [f for f in listdir('data/Perscriptions/') if isfile(join('data/Perscriptions/', f))]

print(onlyfiles)

# For all the files...
for i in np.arange(len(onlyfiles)):
    # load the CSV
    data_temp = pd.read_csv('data/Perscriptions/' + onlyfiles[i], index_col=None,  names=('State', 'County Code', 'Opioid Perscription Rate'))
    
    # Insert the year as a column in the dataframe
    data_temp.insert(0, 'year', onlyfiles[i][-8:-4])
#print(data.head)
    if i == 0:
        data = data_temp
    else:
        data = pd.concat([data, data_temp]) # Add to the overall dataframe


data_sorted = data.sort_values(by=['County Code', 'year'])


data_perscriptions = data_sorted

data_perscriptions.set_index(['County Code', 'year'], inplace=True, drop =False)
# Out:
# ['rxrate_2006.csv', 'rxrate_2007.csv', 'rxrate_2008.csv', 'rxrate_2009.csv', 'rxrate_2010.csv', 'rxrate_2011.csv', 'rxrate_2012.csv', 'rxrate_2013.csv', 'rxrate_2014.csv', 'rxrate_2015.csv', 'rxrate_2016.csv']

# %%
# combine the two dataframes

data = data_mortality.join(data_perscriptions, lsuffix = '_data_mortality', rsuffix = '_data_perscriptions')

print(data_mortality.head(20))
print('break')
print(data_perscriptions.head(20))
print('break')
print(data.head(20))

list(data.columns.values)
# Out:
#                   year Notes              County  County Code Deaths  \
# County Code year
# 1003.0      1999  1999   NaN  Baldwin County, AL       1003.0     11
#             2000  2000   NaN  Baldwin County, AL       1003.0     12
#             2001  2001   NaN  Baldwin County, AL       1003.0     12
#             2002  2002   NaN  Baldwin County, AL       1003.0     16
#             2003  2003   NaN  Baldwin County, AL       1003.0     12
#             2004  2004   NaN  Baldwin County, AL       1003.0     20
#             2005  2005   NaN  Baldwin County, AL       1003.0     22
#             2006  2006   NaN  Baldwin County, AL       1003.0     21
#             2007  2007   NaN  Baldwin County, AL       1003.0     28
#             2008  2008   NaN  Baldwin County, AL       1003.0     27
#             2009  2009   NaN  Baldwin County, AL       1003.0     32
#             2010  2010   NaN  Baldwin County, AL       1003.0     26
#             2011  2011   NaN  Baldwin County, AL       1003.0     24
#             2012  2012   NaN  Baldwin County, AL       1003.0     34
#             2013  2013   NaN  Baldwin County, AL       1003.0     22
#             2014  2014   NaN  Baldwin County, AL       1003.0     38
#             2015  2015   NaN  Baldwin County, AL       1003.0     43
#             2016  2016   NaN  Baldwin County, AL       1003.0     32
# 1009.0      2008  2008   NaN   Blount County, AL       1009.0     17
#             2009  2009   NaN   Blount County, AL       1009.0     11
#
#                  Population         Crude Rate
# County Code year
# 1003.0      1999     137555   8.0 (Unreliable)
#             2000     140415   8.5 (Unreliable)
#             2001     144875   8.3 (Unreliable)
#             2002     147957  10.8 (Unreliable)
#             2003     151509   7.9 (Unreliable)
#             2004     156266               12.8
#             2005     162183               13.6
#             2006     168121               12.5
#             2007     172404               16.2
#             2008     175827               15.4
#             2009     179406               17.8
#             2010     182265               14.3
#             2011     186653               12.9
#             2012     190403               17.9
#             2013     195147               11.3
#             2014     199745               19.0
#             2015     203690               21.1
#             2016     208563               15.3
# 1009.0      2008      57055  29.8 (Unreliable)
#             2009      57341  19.2 (Unreliable)
# break
#                   year State  County Code  Opioid Perscription Rate
# County Code year
# 1001        2006  2006    AL         1001                     134.8
#             2007  2007    AL         1001                     135.8
#             2008  2008    AL         1001                     144.9
#             2009  2009    AL         1001                     147.5
#             2010  2010    AL         1001                     151.7
#             2011  2011    AL         1001                     144.1
#             2012  2012    AL         1001                     157.8
#             2013  2013    AL         1001                     166.7
#             2014  2014    AL         1001                     145.3
#             2015  2015    AL         1001                     129.9
#             2016  2016    AL         1001                     129.6
# 1003        2006  2006    AL         1003                     127.8
#             2007  2007    AL         1003                     133.2
#             2008  2008    AL         1003                     138.3
#             2009  2009    AL         1003                     143.9
#             2010  2010    AL         1003                     143.8
#             2011  2011    AL         1003                     150.0
#             2012  2012    AL         1003                     156.4
#             2013  2013    AL         1003                     154.3
#             2014  2014    AL         1003                     143.5
# break
#                  year_data_mortality Notes              County  \
# County Code year
# 1003.0      1999                1999   NaN  Baldwin County, AL
#             2000                2000   NaN  Baldwin County, AL
#             2001                2001   NaN  Baldwin County, AL
#             2002                2002   NaN  Baldwin County, AL
#             2003                2003   NaN  Baldwin County, AL
#             2004                2004   NaN  Baldwin County, AL
#             2005                2005   NaN  Baldwin County, AL
#             2006                2006   NaN  Baldwin County, AL
#             2007                2007   NaN  Baldwin County, AL
#             2008                2008   NaN  Baldwin County, AL
#             2009                2009   NaN  Baldwin County, AL
#             2010                2010   NaN  Baldwin County, AL
#             2011                2011   NaN  Baldwin County, AL
#             2012                2012   NaN  Baldwin County, AL
#             2013                2013   NaN  Baldwin County, AL
#             2014                2014   NaN  Baldwin County, AL
#             2015                2015   NaN  Baldwin County, AL
#             2016                2016   NaN  Baldwin County, AL
# 1009.0      2008                2008   NaN   Blount County, AL
#             2009                2009   NaN   Blount County, AL
#
#                   County Code_data_mortality Deaths Population  \
# County Code year
# 1003.0      1999                      1003.0     11     137555
#             2000                      1003.0     12     140415
#             2001                      1003.0     12     144875
#             2002                      1003.0     16     147957
#             2003                      1003.0     12     151509
#             2004                      1003.0     20     156266
#             2005                      1003.0     22     162183
#             2006                      1003.0     21     168121
#             2007                      1003.0     28     172404
#             2008                      1003.0     27     175827
#             2009                      1003.0     32     179406
#             2010                      1003.0     26     182265
#             2011                      1003.0     24     186653
#             2012                      1003.0     34     190403
#             2013                      1003.0     22     195147
#             2014                      1003.0     38     199745
#             2015                      1003.0     43     203690
#             2016                      1003.0     32     208563
# 1009.0      2008                      1009.0     17      57055
#             2009                      1009.0     11      57341
#
#                          Crude Rate year_data_perscriptions State  \
# County Code year
# 1003.0      1999   8.0 (Unreliable)                     NaN   NaN
#             2000   8.5 (Unreliable)                     NaN   NaN
#             2001   8.3 (Unreliable)                     NaN   NaN
#             2002  10.8 (Unreliable)                     NaN   NaN
#             2003   7.9 (Unreliable)                     NaN   NaN
#             2004               12.8                     NaN   NaN
#             2005               13.6                     NaN   NaN
#             2006               12.5                    2006    AL
#             2007               16.2                    2007    AL
#             2008               15.4                    2008    AL
#             2009               17.8                    2009    AL
#             2010               14.3                    2010    AL
#             2011               12.9                    2011    AL
#             2012               17.9                    2012    AL
#             2013               11.3                    2013    AL
#             2014               19.0                    2014    AL
#             2015               21.1                    2015    AL
#             2016               15.3                    2016    AL
# 1009.0      2008  29.8 (Unreliable)                    2008    AL
#             2009  19.2 (Unreliable)                    2009    AL
#
#                   County Code_data_perscriptions  Opioid Perscription Rate
# County Code year
# 1003.0      1999                             NaN                       NaN
#             2000                             NaN                       NaN
#             2001                             NaN                       NaN
#             2002                             NaN                       NaN
#             2003                             NaN                       NaN
#             2004                             NaN                       NaN
#             2005                             NaN                       NaN
#             2006                          1003.0                     127.8
#             2007                          1003.0                     133.2
#             2008                          1003.0                     138.3
#             2009                          1003.0                     143.9
#             2010                          1003.0                     143.8
#             2011                          1003.0                     150.0
#             2012                          1003.0                     156.4
#             2013                          1003.0                     154.3
#             2014                          1003.0                     143.5
#             2015                          1003.0                     132.1
#             2016                          1003.0                     123.8
# 1009.0      2008                          1009.0                      58.2
#             2009                          1009.0                      56.2
# ['year_data_mortality',
#  'Notes',
#  'County',
#  'County Code_data_mortality',
#  'Deaths',
#  'Population',
#  'Crude Rate',
#  'year_data_perscriptions',
#  'State',
#  'County Code_data_perscriptions',
#  'Opioid Perscription Rate']

# %%
#print(data.shape)
#print(data['Notes'].iloc[10] == 'nan')

#print(data['Notes'].iloc[13549] != 'nan')

#print(data.Notes != 'nan')
#data[data.Notes !=  'nan']

#print(data.shape)
# Out:
# False

# %%
import re

#re_float = re.compile(r'\d*\.?\d+')


#print(re.findall('\d+', data['Crude Rate']))


import re
temp = np.zeros((data.shape[0],1))
unreliable = np.zeros((data.shape[0],1))
for i in range(data.shape[0]):
    
    
    #print(data['Crude Rate'].iloc[i])
    #s = re.findall('\d*\.?\d+', data['Crude Rate'].iloc[i])
    try:
        temp[i] = float(data['Crude Rate'].iloc[i].split()[0])
        unreliable[i] = 1
    except:
        temp[i] = float(data['Crude Rate'].iloc[i])
        unreliable[i] = 0
        
data['Crude Rate'] =temp
#data = data.assign(unreliable_deat_rate=unreliable)

plt.scatter(data['Opioid Perscription Rate'], data['Crude Rate'])

#data.plot(kind='scatter', x='Opioid Perscription Rate', y='Crude Rate')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-bc528410b230> in <module>()
#      18     try:
# ---> 19         temp[i] = float(data['Crude Rate'].iloc[i].split()[0])
#      20         unreliable[i] = 1
#
# AttributeError: 'numpy.ndarray' object has no attribute 'split'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bc528410b230> in <module>()
#      20         unreliable[i] = 1
#      21     except:
# ---> 22         temp[i] = float(data['Crude Rate'].iloc[i])
#      23         unreliable[i] = 0
#      24
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
print(i)
# Out:
# 13549

# %%
data.iloc[13549]
# Out:
# year_data_mortality                                                            2016
# Notes                             2001 and beyond they have been set to zero. Mo...
# County                                                                          NaN
# County Code_data_mortality                                                      NaN
# Deaths                                                                          NaN
# Population                                                                      NaN
# Crude Rate                        [[8.0], [8.5], [8.3], [10.8], [7.9], [12.8], [...
# year_data_perscriptions                                                         NaN
# State                                                                           NaN
# County Code_data_perscriptions                                                  NaN
# Opioid Perscription Rate                                                        NaN
# Name: (nan, 2016), dtype: object
